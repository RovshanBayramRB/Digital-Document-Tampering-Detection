# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import json
import cv2
import matplotlib.pyplot as plt
import os
import random
from collections import Counter
import shutil

# %%
# # indexes for texts
# # indexes for dates

# text_ls = [2, 3, 5, 6, 7, 8]
# dates_ls = [9, 10, 11]

# %%
# with open('/content/gdrive/MyDrive/DiplomaWorkRB/annotations/svk_id.json') as f:
#    data = json.load(f)

# %%
# data['_via_img_metadata']['00.jpg353386']['regions']

# %%
# os.chdir('/content/gdrive/MyDrive/DiplomaWorkRB/images/svk_id/')

# %%
# image_ls = os.listdir()

# %%
# count = 24020

# attr_ls = [9, 10, 11]

# for i in image_ls:
  
#   break_count = 0
#   already_used = []

#   while True:

#     image = cv2.imread('/content/gdrive/MyDrive/DiplomaWorkRB/images/srb_passport/'+i)

#     for j in data['_via_img_metadata'].keys():
#       if i in j:
#         details_data = data['_via_img_metadata'][j]

#     if break_count >= 30:
#       break

#     else:
#       break_count = break_count + 1

#       first_attr = attr_ls[random.randint(0, 2)]
#       second_attr = attr_ls[random.randint(0, 2)]


#       if first_attr == second_attr:
#         continue
#       elif [first_attr, second_attr] in already_used:
#         continue
#       else:
#         already_used.append([first_attr, second_attr])


#         x_bd = int(details_data['regions'][first_attr]['shape_attributes']['x'])
#         y_bd = int(details_data['regions'][first_attr]['shape_attributes']['y'])
#         width_bd = int(details_data['regions'][first_attr]['shape_attributes']['width'])
#         height_bd = int(details_data['regions'][first_attr]['shape_attributes']['height'])

#         crop_img1 = image[y_bd:y_bd+height_bd, x_bd:x_bd+width_bd]

#         x_id = int(details_data['regions'][second_attr]['shape_attributes']['x'])
#         y_id = int(details_data['regions'][second_attr]['shape_attributes']['y'])
#         width_id = int(details_data['regions'][second_attr]['shape_attributes']['width'])
#         height_id = int(details_data['regions'][second_attr]['shape_attributes']['height'])

#         crop_img2 = image[y_id:y_id+height_id, x_id:x_id+width_id]


#         resized2 = cv2.resize(crop_img2, (crop_img1.shape[1], crop_img1.shape[0]))


#         #Pasting second part of image to the place of first one
#         image[y_bd:y_bd+height_bd, x_bd:x_bd+width_bd] = resized2
#         cv2.imwrite('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/TamperedImages/' + str(count) + '_tampered.jpg', image)


#         #Labeling

#         #Coloring the whole image to black
#         image[:] = [0, 0, 0]

#         #Coloring tampered area to white
#         image[y_bd:y_bd+height_bd, x_bd:x_bd+width_bd] = [255, 255, 255]
#         cv2.imwrite('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/Labels/' + str(count) +  '_label.jpg', image)

#         print(count)
#         count += 1

# %% [markdown]
# # Fixing Bugs

# %%
# os.rename("path/to/current/file.foo", "path/to/new/destination/for/file.foo")
# os.replace("path/to/current/file.foo", "path/to/new/destination/for/file.foo")
# shutil.move("path/to/current/file.foo", "path/to/new/destination/for/file.foo")

# %%
os.chdir('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/FinalTampereds/img')
image_ls = os.listdir()

os.chdir('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/FinalLabels/img')
labels_ls = os.listdir()

# %%
print("Tampereds", len(image_ls))
print("Labels", len(labels_ls))
# Out:
# Tampereds 21698
# Labels 21698

# %%
# count = 5000

# for i in image_ls:

#   tamper = cv2.imread('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/FinalTampered/' + i)
#   label = cv2.imread('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/FinalLabels/' + i.split('_')[0] + '_label.jpg')

#   cv2.imwrite('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/TamperedLast/' + str(count) +  '_tampered.jpg', tamper)
#   cv2.imwrite('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/LabelsLast/' + str(count) +  '_label.jpg', label)

#   print(count)
#   count = count + 1

# %%
# count = 1

# for i in image_ls:
#   if i.split('_')[0] + '_label.jpg' in labels_ls:
#     shutil.move('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/TamperedImages/' + i, '/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/FinalTampered')
#     shutil.move('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/Labels/' + i.split('_')[0] + '_label.jpg', '/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/FinalLabels')

#     print(count)
#     count = count + 1

# %%
import random

# %%
random.randint(10, 20)
# Out:
# 20

# %%
# c = 1
# ls = []

# while True:
#   index = random.randint(1, 21693)

#   if index in ls:
#     continue
#   else:

#     ls.append(index)

#     i = image_ls[index]

#     shutil.move('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/FinalTampereds/img/' + i, '/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/TrainingImages/img')
#     shutil.move('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/FinalLabels/img/' + i.split('_')[0] + '_label.jpg', '/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/TrainingMasks/img')
#     print(c)
#     c = c + 1

#   if c >= 6002:
#     break

# %%
# import glob

# %%
# all_imgs = glob.glob('XXX/LabelsLast/*.jpg)
# for imgPath in all_imgs:
#      os.rename(imgPath, imgPath.replace('_label', '_tampered'))

# %%
# os.chdir('/content/gdrive/MyDrive/DiplomaWorkRB/AnnotatedData/TrainingMasks/img')
# mask_ls = os.listdir()

# %%
# for i in mask_ls:
#   os.rename(i, i.split('_')[0] + '_tampered.jpg')

# %%
# os.rename("tutorialsdir","tutorialsdirectory")

# %%
# i = mask_ls[0]

# %%
# i.split('_')[0] + '_tampered.jpg'
